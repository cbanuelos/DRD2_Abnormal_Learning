# %% [markdown]
# # VS associations with cognitive performance (P) with an interaction with DRD2 polymorphism
#
# ***

# %%
import matplotlib.pyplot as plt
import ptitprince as pt
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.compat import unicode
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from IPython.core.display import HTML

# %% [markdown]
# ### Loading Datasets

# %%
# Loading data
data = pd.read_csv('DRD2_subset_data.csv', delimiter=',')
data = data.dropna(subset=['P','Q','VS','DRD2', 'AGE', 'female_1'])

# Loading second IGT only data (Reformatted)
IGT_data = pd.read_csv('DRD2_IGT_subset_data.csv', delimiter=',')
IGT_data = IGT_data.dropna(subset=['IGT_scores', 'DRD2'])

# %% [markdown]
# ### Reformatting Data

# %%
# Changing Categorical data to integers
data['DRD2'] = data['DRD2'].astype(int)
data['female_1'] = data['female_1'].astype(int)
IGT_data['DRD2'] = IGT_data['DRD2'].astype(int)

# Changing DRD2 data to category type
data['DRD2_cat'] = pd.cut(data['DRD2'], range(-1,2,1), labels=['Ins/Ins Carrier', 'Non-Carrier'])
data['DRD2_cat'] = data['DRD2_cat'].astype('object')
IGT_data['DRD2_cat'] = pd.cut(IGT_data['DRD2'], range(-1,2,1), labels=['Ins/Ins Carrier', 'Non-Carrier'])
IGT_data['DRD2_cat'] = IGT_data['DRD2_cat'].astype('object')

# Splitting data based on DRD2 polymorphism
low = data[data['DRD2'] == 1] # Low D2 Receptors
normal = data[data['DRD2'] == 0] # Normal D2 Receptors

# %% [markdown]
# ## Distribution Plots

# %%
# Setting style of figures
sns.set_context("notebook", font_scale=1.5)

# Configuring 1st row of grid of plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.2)
fig.set_figheight(8)
fig.set_figwidth(20)

# Age Rain Cloud Plot
ax = fig.add_subplot(1, 3, 1)
age = pt.RainCloud(y='AGE', orient='h',data=data, width_viol=.4, width_box=.1, figsize=(7,5), 
                   palette="Blues",ax=ax)
age.set(xlabel='\n Age')

# VS Rain Cloud Plot
ax = fig.add_subplot(1, 3, 2)
VS = pt.RainCloud(y='VS', x='DRD2', data=data, orient='h', width_viol=.4, width_box=.2, figsize=(7,5), 
                  palette="Blues", ax=ax)
VS.set(xlabel='\n VS', title='\n Distributions of Measures \n')

# IGT Scores Rain Cloud Plots
ax = fig.add_subplot(1, 3, 3)
IGT = pt.RainCloud(y='IGT_scores', x='IGT_score_type', hue='DRD2_cat', data=IGT_data, orient='h', 
                         width_viol=.4, width_box=.1, figsize=(7,5), palette='Blues', alpha=.6, ax=ax,
                          dodge=True, pointplot=True) #Can comment out if lines aren't helpful
IGT.set(xlabel='\n Scores', ylabel='\n IGT Score Types')

# Configuring 2nd row of grid of plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=.3)
fig.set_figheight(8)
fig.set_figwidth(22)

# Sex Bar Plot
ax = fig.add_subplot(1, 2, 1)
sex = sns.catplot(x="female_1", kind="count", data=data, palette="Blues", ax=ax)
ax.set(xlabel='\n Sex (1 == Female)', ylabel='\n Count \n')

# DRD2 Bar Plot
ax = fig.add_subplot(1, 2, 2)
DRD2 = sns.catplot(x="DRD2", kind="count", data=data, palette="Blues", ax=ax)
ax.set(xlabel='\n DRD2 (1 == Ins/Ins Carrier)', ylabel='\n Count \n')
plt.close(3)
plt.close(4)
plt.show()

# %% [markdown]
# ***
#
#
# # T-Tests

# %% [markdown]
# ### T-Test between DRD2 vs P and Q

# %%
t_test_results = stats.ttest_ind(low.iloc[:,2:5], normal.iloc[:,2:5], equal_var=True)
cols = ['P', 'Q', 'VS']
pd.DataFrame({'Statistics':t_test_results.statistic[0:], 'P-values':t_test_results.pvalue}, cols)
# Out:
#     Statistics  P-values
# P    -3.230837  0.001328
# Q     0.539049  0.590128
# VS   -1.771730  0.077138

# %% [markdown]
# ### Linear Regression Plots

# %%
# Configuring grid of plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.2)
fig.set_figheight(8)
fig.set_figwidth(20)

# P vs VS between DRD2 groups Scatter Plot
ax = fig.add_subplot(1, 2, 1)
scatter_P_low = sns.regplot(x='VS', y='P', data=low, label='Ins/Ins Carrier', color="darkblue", ax=ax).legend()
scatter_P_normal = sns.regplot(x='VS', y='P', data=normal, label='Non-Carrier').legend()
ax.set(title='P vs VS between DRD2 groups \n')

# Q vs VS between DRD2 groups Scatter Plot
ax = fig.add_subplot(1, 2, 2)
scatter_Q_low = sns.regplot(x='VS', y='Q', data=low, label='Ins/Ins Carrier', color="darkblue", ax=ax).legend()
scatter_Q_normal = sns.regplot(x='VS', y='Q', data=normal, label='Non-Carrier').legend()
ax.set(title='Q vs VS between DRD2 groups \n')
plt.show()

# %% [markdown]
# *****
#
#
# # Linear Regression

# %% [markdown]
# ## P ~ DRD2 + VS + DRD2 * VS

# %%
results_P = smf.ols(formula='P ~ DRD2 + VS + DRD2 * VS',data=data).fit()
HTML(results_P.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   16.7039</td> <td>    2.020</td> <td>    8.269</td> <td> 0.000</td> <td>   12.733</td> <td>   20.674</td>
# </tr>
# <tr>
#   <th>DRD2</th>      <td>   -8.7905</td> <td>    3.634</td> <td>   -2.419</td> <td> 0.016</td> <td>  -15.932</td> <td>   -1.649</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>   21.1400</td> <td>   10.020</td> <td>    2.110</td> <td> 0.035</td> <td>    1.447</td> <td>   40.833</td>
# </tr>
# <tr>
#   <th>DRD2:VS</th>   <td>   -9.5730</td> <td>   18.830</td> <td>   -0.508</td> <td> 0.611</td> <td>  -46.582</td> <td>   27.436</td>
# </tr>
# </table>

# %% [markdown]
# ## Q ~ DRD2 + VS + DRD2 * VS

# %%
results_Q = smf.ols(formula='Q ~ DRD2 + VS + DRD2 * VS',data=data).fit()
HTML(results_Q.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   30.6606</td> <td>    1.746</td> <td>   17.563</td> <td> 0.000</td> <td>   27.230</td> <td>   34.092</td>
# </tr>
# <tr>
#   <th>DRD2</th>      <td>    1.7348</td> <td>    3.140</td> <td>    0.553</td> <td> 0.581</td> <td>   -4.437</td> <td>    7.906</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>    4.7830</td> <td>    8.658</td> <td>    0.552</td> <td> 0.581</td> <td>  -12.234</td> <td>   21.801</td>
# </tr>
# <tr>
#   <th>DRD2:VS</th>   <td>   -1.3082</td> <td>   16.272</td> <td>   -0.080</td> <td> 0.936</td> <td>  -33.289</td> <td>   30.673</td>
# </tr>
# </table>

# %% [markdown]
# ### Permutation Test

# %%
np.random.seed(123)

def permutationTest(y, coef):
    
    coef_collection = []
    greaterCoef_count = 0
    total = 1500
    
    for i in range(0,total):
        y_rand = np.random.choice(data[y],438, replace=False)
        DRD2_rand = np.random.choice(data['DRD2'],438)
        VS_rand = np.random.choice(data['VS'],438)
        rand_data = pd.DataFrame(data={'DRD2':DRD2_rand, 'VS':VS_rand, 'y':y_rand})
        results_rand = smf.ols(formula= 'y ~ DRD2 + VS + DRD2 * VS', data=rand_data).fit()
        coef_collection.append(results_rand.params[2])
        
        if results_rand.params[2] > coef:
            greaterCoef_count += 1
    
    PVal  = greaterCoef_count / total
    
    plt.hist(coef_collection, bins=25, edgecolor='k')
    plt.axvline(x=coef, color='black', linestyle='dashed')
    
    return PVal

# %%
permutationTest('P', results_P.params[2])
# Out:
# 0.012

# %%
permutationTest('Q', results_Q.params[2])
# Out:
# 0.2733333333333333

# %% [markdown]
# ***
#
# # Between Groups

# %%
carrier = data[data['DRD2'] == 1]
noncarrier = data[data['DRD2'] == 0]

# %% [markdown]
# ## P ~  VS

# %% [markdown]
# #### Ins/Ins Carriers

# %%
results_P_carrier = smf.ols(formula='P ~ VS',data=carrier).fit()
HTML(results_P_carrier.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>    7.9134</td> <td>    2.939</td> <td>    2.692</td> <td> 0.008</td> <td>    2.092</td> <td>   13.734</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>   11.5671</td> <td>   15.515</td> <td>    0.746</td> <td> 0.457</td> <td>  -19.159</td> <td>   42.293</td>
# </tr>
# </table>

# %% [markdown]
# #### Non-Carriers

# %%
results_P_noncarrier = smf.ols(formula='P ~ VS', data=noncarrier).fit()
HTML(results_P_noncarrier.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   16.7039</td> <td>    2.040</td> <td>    8.189</td> <td> 0.000</td> <td>   12.691</td> <td>   20.717</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>   21.1400</td> <td>   10.117</td> <td>    2.090</td> <td> 0.037</td> <td>    1.235</td> <td>   41.045</td>
# </tr>
# </table>

# %% [markdown]
# ## Q ~  VS

# %% [markdown]
# #### Ins/Ins Carriers

# %%
results_Q_carrier = smf.ols(formula='Q ~ VS',data=carrier).fit()
HTML(results_Q_carrier.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   32.3955</td> <td>    2.426</td> <td>   13.353</td> <td> 0.000</td> <td>   27.591</td> <td>   37.200</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>    3.4748</td> <td>   12.806</td> <td>    0.271</td> <td> 0.787</td> <td>  -21.887</td> <td>   28.837</td>
# </tr>
# </table>

# %% [markdown]
# #### Non-Carriers

# %%
results_Q_noncarrier = smf.ols(formula='Q ~ VS',data=noncarrier).fit()
HTML(results_Q_noncarrier.summary().tables[1].as_html())
# Out:
# <table class="simpletable">
# <tr>
#       <td></td>         <th>coef</th>     <th>std err</th>      <th>t</th>      <th>P>|t|</th>  <th>[0.025</th>    <th>0.975]</th>
# </tr>
# <tr>
#   <th>Intercept</th> <td>   30.6606</td> <td>    1.789</td> <td>   17.139</td> <td> 0.000</td> <td>   27.141</td> <td>   34.180</td>
# </tr>
# <tr>
#   <th>VS</th>        <td>    4.7830</td> <td>    8.873</td> <td>    0.539</td> <td> 0.590</td> <td>  -12.674</td> <td>   22.240</td>
# </tr>
# </table>

# %%
np.random.seed(123)

def permutationTest(y, difference, length):
    
    coef_collection = []
    greaterCoef_count = 0
    total = 1500
    
    for i in range(0,total):
        
        # Carrier Linear Regression
        y_car_rand = np.random.choice(carrier[y],length, replace=False)
        VS_car_rand = np.random.choice(carrier['VS'],length)
        rand_car_data = pd.DataFrame(data={'VS':VS_car_rand, 'y':y_car_rand})
        results_car_rand = smf.ols(formula= 'y ~ VS', data=rand_car_data).fit()
        car_coef = results_car_rand.params[1]
        
        # Non-Carrier Linear Regression
        y_non_rand = np.random.choice(noncarrier[y],length, replace=False)
        VS_non_rand = np.random.choice(noncarrier['VS'],length)
        rand_non_data = pd.DataFrame(data={'VS':VS_non_rand, 'y':y_non_rand})
        results_non_rand = smf.ols(formula= 'y ~ VS', data=rand_non_data).fit()
        non_coef = results_non_rand.params[1]
        
        
        
        coef_collection.append(results_car_rand.params[1])
        
        if results_rand.params[1] > coef:
            greaterCoef_count += 1
    
    PVal  = greaterCoef_count / total
    
    plt.hist(coef_collection, bins=25, edgecolor='k')
    plt.axvline(x=coef, color='black', linestyle='dashed')
    
    return PVal

# %%
permutationTest('P', results_P_carrier.params[1]- results_P_noncarrier.params[1])
# Out:
# 0.23333333333333334

# %%
permutationTest('P', results_P_noncarrier.params[1], noncarrier, 319)
# Out:
# 0.018666666666666668

# %%
permutationTest('Q', results_Q_carrier.params[1], carrier, 119)
# Out:
# 0.356

# %%
permutationTest('Q', results_Q_noncarrier.params[1], noncarrier, 319)
# Out:
# 0.29
